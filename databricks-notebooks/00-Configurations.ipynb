# %%
storage_account = "prstrgacc"

bronze_container = "bronze"
silver_container = "silver"
gold_container = "gold"

bronze_path = f"abfss://f1-data@{storage_account}.dfs.core.windows.net/{bronze_container}"
silver_path = f"abfss://f1-data@{storage_account}.dfs.core.windows.net/{silver_container}"
gold_path = f"abfss://f1-data@{storage_account}.dfs.core.windows.net/{gold_container}"
